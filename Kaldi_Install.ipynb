# %% [markdown]
# <a href="https://colab.research.google.com/github/arm-on/kaldi-colab/blob/master/Kaldi_Install.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Google Drive Authentication**

# %%
from google.colab import drive
drive.mount('/gdrive', force_remount=True)
# %cd /gdrive/My Drive/kaldi-asr/

# %%
#!rm -r /opt/kaldi

# %% [markdown]
# **Getting Kaldi using the kora library**

# %%
# !pip install kora -q

# %%
import kora.install.kaldi

# %% [markdown]
# You need to download SRILM from http://www.speech.sri.com/projects/srilm/ and then move it to kaldi/tools/

# %%
#!mv  /gdrive/MyDrive/srilm-1.7.3.tar.gz /opt/kaldi/tools/srilm-1.7.3.tar.gz

# %% [markdown]
# **Checking for the needed libraries/dependencies**

# %%
# !cd /opt/kaldi/tools  && extras/check_dependencies.sh

# %% [markdown]
# **Installing the libraries needed by Kaldi**

# %%
# !sudo apt-get install sox

# %%
# !cd /opt/kaldi/tools && extras/install_mkl.sh

# %%
# !cd /opt/kaldi/tools && extras/check_dependencies.sh

# %% [markdown]
# **Installing Kaldi (cont.)**

# %%
# !cd /opt/kaldi/tools && make -j 8

# %% [markdown]
# Installing the Language Model

# %%
# !cd /opt/kaldi/tools && extras/install_irstlm.sh

# %%
# !cd /opt/kaldi/src && ./configure --shared  && make depend -j 8 && make -j 8

# %%
# !du -hs /opt/kaldi
